# %%
import pandas as pd
import missingno as msno
import plotly.express as px
import datetime

# %%
df = pd.read_csv('retouren.csv')

df.head()
# Out:
#    order_item_id  order_date delivery_date  item_id item_size item_color  \
# 0              1  2016-06-22    2016-06-27      643        38       navy
# 1              2  2016-06-22           NaN      337       152       grey
# 2              3  2016-06-22    2016-06-27      270       xxl       grey
# 3              4  2016-06-22    2016-06-27      142       xxl       grey
# 4              5  2016-06-22    2016-06-27      561       xxl       grey
#
#    brand_id  item_price  user_id user_title    user_dob          user_state  \
# 0        30       49.90    30822        Mrs  1969-04-17              Saxony
# 1        30       19.95    30822        Mrs  1969-04-17              Saxony
# 2        49       79.90    30823        Mrs  1970-04-22  Baden-Wuerttemberg
# 3        49       99.90    30823        Mrs  1970-04-22  Baden-Wuerttemberg
# 4         3       14.90    30823        Mrs  1970-04-22  Baden-Wuerttemberg
#
#   user_reg_date  return
# 0    2016-06-23       0
# ...

# %%
timestamp = datetime.datetime.now()
df['account_age'] = pd.to_datetime(df.user_reg_date).apply(lambda x: (timestamp-x).days)

# %%
df.head()
# Out:
#    order_item_id  order_date delivery_date  item_id item_size item_color  \
# 0              1  2016-06-22    2016-06-27      643        38       navy
# 1              2  2016-06-22           NaN      337       152       grey
# 2              3  2016-06-22    2016-06-27      270       xxl       grey
# 3              4  2016-06-22    2016-06-27      142       xxl       grey
# 4              5  2016-06-22    2016-06-27      561       xxl       grey
#
#    brand_id  item_price  user_id user_title    user_dob          user_state  \
# 0        30       49.90    30822        Mrs  1969-04-17              Saxony
# 1        30       19.95    30822        Mrs  1969-04-17              Saxony
# 2        49       79.90    30823        Mrs  1970-04-22  Baden-Wuerttemberg
# 3        49       99.90    30823        Mrs  1970-04-22  Baden-Wuerttemberg
# 4         3       14.90    30823        Mrs  1970-04-22  Baden-Wuerttemberg
#
#   user_reg_date  return  account_age
# ...

# %%
df.groupby('user_title').agg({'user_title': 'count'})
# Out:
#               user_title
# user_title
# Company               90
# Family               321
# Mr                  2867
# Mrs                71630
# not reported          99

# %%
px.scatter(df, df.user_id, df.account_age)

# %%
df[df.item_size == "37+"]
# Out:
#        order_item_id  order_date delivery_date  item_id item_size item_color  \
# 4050            4051  2016-06-26    2016-06-28      177       37+      brown
# 4415            4416  2016-06-26           NaN      117       37+      black
# 11901          11902  2016-06-28    2016-07-03      395       37+    stained
# 12164          12165  2016-06-28    2016-07-27      593       37+       blue
# 13263          13264  2016-06-28    2016-07-03      395       37+    stained
# 15995          15996  2016-06-29    2016-07-04      839       37+      black
# 18132          18133  2016-06-29    2016-07-03      236       37+      brown
# 18179          18180  2016-06-29    2016-07-18      395       37+    stained
# 19064          19065  2016-06-30    2016-07-18      395       37+    stained
# 19907          19908  2016-06-30           NaN      395       37+    stained
# 21506          21507  2016-07-01    2016-07-18      177       37+      brown
# ...
